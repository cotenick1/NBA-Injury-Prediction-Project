# %%
# !pip install selenium
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
driver = webdriver.Chrome()

driver.get('https://cleaningtheglass.com/stats/players?season=2018')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/selenium/webdriver/common/service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# ~/anaconda3/envs/dsi/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# ...

# %%
driver.find_element_by_id("click_to_login").click()

# %%
driver.switch_to.frame(driver.find_element_by_tag_name('iframe'))

# %%
driver.find_element_by_id('login').send_keys('noah.a.christiansen@gmail.com')
driver.find_element_by_id('password').send_keys('Vonnegut12')
driver.find_element_by_class_name('button').click()

# %%
driver.switch_to.default_content()

# %%
table = driver.find_element_by_class_name('stat_table_container')

# %%
season = table.text

# %%
season.split('\n')
# Out:
# ['Player',
#  'Age',
#  'Team',
#  'Pos',
#  'MIN',
#  'Usage',
#  'PSA',
#  'AST%',
#  'AST:Usg',
#  'TOV%',
#  '%',
#  '#',
#  '%',
#  '#',
#  '%',
#  '#',
#  '%',
#  '#',
#  '%',
#  '#',
#  'Alex Abrines 25.2 OKC Wing 559 8 11.3% 24 101.3 6 4.7% 13 0.41 82 8.5%',
#  'Quincy Acy 28.0 PHX Big 103 2 9.6% 0 70.0 42 8.0% 86 0.84 21 15.4%',
#  'Jaylen Adams 22.4 ATL Point 396 2 15.4% 9 94.1 20 21.0% 76 1.36 13 16.4%',
#  'Steven Adams 25.2 OKC Big 2679 34 14.9% 58 117.4 18 6.3% 21 0.42 43 13.8%',
#  'Bam Adebayo 21.2 MIA Big 1877 45 16.1% 80 125.2 84 14.8% 91 0.92 11 17.5%',
#  'Deng Adel 21.7 CLE Forward 187 3 9.9% 3 81.1 1 3.2% 8 0.32 15 14.6%',
#  'LaMarcus Aldridge 33.2 SAS Big 2699 94 25.5% 53 115.8 71 11.5% 26 0.45 88 9.4%',
#  'Rawle Alkins 21.0 CHI Forward 108 69 18.6% 4 89.7 83 13.4% 82 0.72 4 16.7%',
#  'Grayson Allen 23.0 UTA Combo 322 66 21.8% 47 106.3 3 9.1% 0 0.42 12 15.6%',
#  'Jarrett Allen 20.5 BKN Big 2094 29 14.5% 79 124.9 34 7.6% 41 0.52 35 14.5%',
# ...
